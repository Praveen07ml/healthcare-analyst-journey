# %%
count = 0
for number in range(1,51):
    if number % 5 == 0:
        count += 1
print(count)
# Out:
# 10

# %%
word = "Hello World"
vowels = "aeiouAEIOU"
count = 0
for char in word:
    if char in vowels:
        count += 1
print(count)
# Out:
# 3

# %%
numbers = [23,15,28,39,12]
count = 0
for number in numbers:
    if number > 15:
        count += 1
print(count)
# Out:
# 3

# %%
count = 0
for number in range(1,101):
    if number % 3 == 0  and number % 5 == 0:
        count += 1
print(count)
# Out:
# 6

# %%
count = 0
for number in range(1,51):
    if number % 3 == 0 or number % 7 == 0:
        count += 1
print(count)
# Out:
# 21

# %%
count = 0
words = " Python is a Programming Language"
for word in words.split():
    if len(word) > 5:
        count += 1
print(count)
# Out:
# 3

# %%
count = 0
for number in range(1,31):
    if number > 1:
        prime = True
        for i in range(2,number):
            if number % i == 0:
                prime = False
                break
        if prime:
            count += 1
print(count)
# Out:
# 10

# %%
numbers = [15,22,8,45,12,33,7]
count = 0

for number in numbers:
    if number % 2 == 0 and number > 10:
        count += 1
print(count)
# Out:
# 2

# %%
word = "programming123"
count = 0
for char in word:
    if char.isdigit():
        count += 1
print(count)
# Out:
# 3

# %%
total = 0
for number in range(1,101):
    total += number
print(total)
# Out:
# 5050

# %%
total = 0
for number in range(1,51):
    if number % 2 == 0:
        total += number
print(total)
# Out:
# 650

# %%
numbers = [5,12,8,23,15]
total = 0
for number in numbers:
    total += number
print(total)
# Out:
# 63

# %%
product = 1
for number in range(1,11):
    product *= number
print(product)
# Out:
# 3628800

# %%
factorial = 1
for number in range(5,0,-1):
    factorial *= number
print(factorial)
# Out:
# 120

# %%
numbers = [10,20,30,40,50]
total = 0
count = 0
for number in numbers:
    total += number
    count += 1
print(total/count)
# Out:
# 30.0

# %%
numbers = [34,12,78,23,90,30]
largest = numbers[0]
for number in numbers:
    if number > largest:
        largest = number
print(largest)
# Out:
# 90

# %%
numbers =  [34,12,78,23,90,30]
smallest = numbers[0]
for number in numbers:
    if number < smallest:
        smallest = number
print(smallest)
# Out:
# 12

# %%
words = "Python programming is incridiblly fun"
longest = ""
for word in words.split():
    if len(word) > len(longest):
        longest = word
print(longest)
# Out:
# programming

# %%
count = 0
numbers = []
for number in range(1,51):
    if int(number ** 0.5) ** 2 == number:
        count += 1
        numbers.append(number)
print(count)
print(numbers)
# Out:
# 7
# [1, 4, 9, 16, 25, 36, 49]

# %%
total = 0 
for number in range(1,51):
    if number % 2 != 0:
        total += number
print(total)
# Out:
# 625

# %%
numbers = [15,22,8,45,18]
largest = numbers[0]
for number in numbers:
    if number > largest:
        largest = number
print(largest)
# Out:
# 45

# %%
words = "Mechine learning is the fun"
count = 0
word = []
for char in words:
    if char == "M"or char == "m":
        count += 1
        word.append(char)
print(count)
# Out:
# 1
# ['M']

# %%
numbers = "2345"
product = 1
for number in numbers:
    product *= int(number)
print(product)
# Out:
# 120

# %%
numbers = [12,34,50,75]
found = False
for number in numbers:
    if number == 50:
        found = True
        break
print(found)
# Out:
# True

# %%
word = "amazing"
found = False
for char in word:
    if char == "z":
        found = True
        break
print(found)
# Out:
# True

# %%
numbers = [5,12,8,15,20]
found = False
for number in numbers:
    if number > 15:
        found = True
        break
print(found)
# Out:
# True

# %%
word = "banana"
found = False
for char in word:
    if char == 'a':
        print(word.index(char))
        break
print(found)
# Out:
# 1
# True

# %%
numbers = [15,23,8,17,12,9]
for number in numbers:
    if number % 2 == 0:
        print(numbers.index(number))
        break
# Out:
# 2

# %%
numbers = [3,7,12,8,15,20]
numbers.sort()
found = False
for i in range(len(numbers)-1):
    if numbers[i] == numbers[i+1]:
        found = True
        break
print(found)
# Out:
# False

# %%
numbers = list(range(1,11))
result = []
for number in numbers:
    if number % 2 == 0:
        result.append(number)
print(result)
# Out:
# [2, 4, 6, 8, 10]

# %%
words = "Python is great programming language"
result = []

for word in words.split():
    if len(word) > 4:
        result.append(word)
print(result)
# Out:
# ['Python', 'great', 'programming', 'language']

# %%
numbers = [5,-2,8,-7,3,-1,9,-4]

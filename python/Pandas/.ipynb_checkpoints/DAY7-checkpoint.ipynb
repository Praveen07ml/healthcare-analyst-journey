# %% [markdown]
# #### Pandas Basic understaing of data

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\prave\OneDrive\Desktop\ai-engineer-journey\csv_files\Online_Retail.csv",encoding='latin1')

# %% [markdown]
# #### Understaning how Big data was

# %%
rows = df.shape[0]
columns = df.shape[1]
total_data = df.shape[0] * df.shape[1]

print(f"total rows {rows}")
print(f"total columns {columns}")
print(f"total data points {total_data}")
# Out:
# total rows 541909
# total columns 8
# total data points 4335272

# %% [markdown]
# #### Understaning each column

# %%
for i,column in enumerate(df.columns):
    print(f"{i+1}. {column}")
# Out:
# 1. InvoiceNo
# 2. StockCode
# 3. Description
# 4. Quantity
# 5. InvoiceDate
# 6. UnitPrice
# 7. CustomerID
# 8. Country

# %% [markdown]
# #### Reading sample data

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
df.tail()
# Out:
#        InvoiceNo StockCode                      Description  Quantity  \
# 541904    581587     22613      PACK OF 20 SPACEBOY NAPKINS        12
# 541905    581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906    581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907    581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908    581587     22138    BAKING SET 9 PIECE RETROSPOT          3
#
#              InvoiceDate  UnitPrice  CustomerID Country
# 541904  09-12-2011 12:50       0.85     12680.0  France
# 541905  09-12-2011 12:50       2.10     12680.0  France
# 541906  09-12-2011 12:50       4.15     12680.0  France
# 541907  09-12-2011 12:50       4.15     12680.0  France
# 541908  09-12-2011 12:50       4.95     12680.0  France

# %%
df.sample(5)
# Out:
#        InvoiceNo StockCode                     Description  Quantity  \
# 227372    556845     23054  RECYCLED ACAPULCO MAT LAVENDER         2
# 118288    546427     21468    BUTTERFLY CROCHET FOOD COVER         1
# 20867     538071     21981    PACK OF 12 WOODLAND TISSUES          3
# 281339    561515     20707    CRAZY DAISY HEART DECORATION         2
# 433581    573932     21495      SKULLS AND CROSSBONES WRAP       200
#
#              InvoiceDate  UnitPrice  CustomerID         Country
# 227372  15-06-2011 11:30       8.25     17511.0  United Kingdom
# 118288  13-03-2011 14:29       3.75     14606.0  United Kingdom
# 20867   09-12-2010 14:09       0.85         NaN  United Kingdom
# 281339  27-07-2011 15:16       0.83         NaN  United Kingdom
# 433581  02-11-2011 10:26       0.36     17966.0  United Kingdom

# %% [markdown]
# #### Understaning Column data types

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# #### Basic Statistics

# %%
df.describe()
# Out:
#             Quantity      UnitPrice     CustomerID
# count  541909.000000  541909.000000  406829.000000
# mean        9.552250       4.611114   15287.690570
# std       218.081158      96.759853    1713.600303
# min    -80995.000000  -11062.060000   12346.000000
# 25%         1.000000       1.250000   13953.000000
# 50%         3.000000       2.080000   15152.000000
# 75%        10.000000       4.130000   16791.000000
# max     80995.000000   38970.000000   18287.000000

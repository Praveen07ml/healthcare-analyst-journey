# %% [markdown]
# #### Resuming What i left

# %%
import pandas as pd

# %%
data = {
    'name':['praveen','Dhanush','Srinu','Kanaka'],
    'city':['Hyd','Hyd','Gondi','Kuwait'],
    'age':[25,23,49,45]
}


df = pd.DataFrame(data)
df
# Out:
#       name    city  age
# 0  praveen     Hyd   25
# 1  Dhanush     Hyd   23
# 2    Srinu   Gondi   49
# 3   Kanaka  Kuwait   45

# %%
df['name']
# Out:
# 0    praveen
# 1    Dhanush
# 2      Srinu
# 3     Kanaka
# Name: name, dtype: object

# %%
df.shape
# Out:
# (4, 3)

# %%
df.head(2)
# Out:
#       name city  age
# 0  praveen  Hyd   25
# 1  Dhanush  Hyd   23

# %%
df.tail(2)
# Out:
#      name    city  age
# 2   Srinu   Gondi   49
# 3  Kanaka  Kuwait   45

# %%
df['gender'] = ['male','male,','male','female']
df
# Out:
#       name    city  age  gender
# 0  praveen     Hyd   25    male
# 1  Dhanush     Hyd   23   male,
# 2    Srinu   Gondi   49    male
# 3   Kanaka  Kuwait   45  female

# %%
df
# Out:
#       name    city  age  gender
# 0  praveen     Hyd   25    male
# 1  Dhanush     Hyd   23   male,
# 2    Srinu   Gondi   49    male
# 3   Kanaka  Kuwait   45  famale

# %%
df[df['age']>25]
# Out:
#      name    city  age  gender
# 2   Srinu   Gondi   49    male
# 3  Kanaka  Kuwait   45  famale

# %%
df[(df['age']>25) & (df['gender']=='female')]
# Out:
#      name    city  age  gender
# 3  Kanaka  Kuwait   45  female

# %%
df.sort_values('age',ascending=False)
# Out:
#       name    city  age  gender
# 2    Srinu   Gondi   49    male
# 3   Kanaka  Kuwait   45  female
# 0  praveen     Hyd   25    male
# 1  Dhanush     Hyd   23   male,

# %%
df.sort_values('age',ascending=True)
# Out:
#       name    city  age  gender
# 1  Dhanush     Hyd   23   male,
# 0  praveen     Hyd   25    male
# 3   Kanaka  Kuwait   45  female
# 2    Srinu   Gondi   49    male

# %%
df[['name','city']]
# Out:
#       name    city
# 0  praveen     Hyd
# 1  Dhanush     Hyd
# 2    Srinu   Gondi
# 3   Kanaka  Kuwait

# %% [markdown]
# ### EDA (Top Findings without writing pandas code)
#
# - Total Transaction records `541909`
# - Total unique InvoiceNo - `25900`
# - Total unique StockID  - `4070`
# - Total unique CustomerID - `4372`
# - Top country most concentrated geography `United Kingdom` with `495478`
# - Most frequent product item `WHITE HANGING HEART T-LIGHT HOLDER`  with  `2369`
# - Avg Unit Price - `4.61`
# - Data Range from `01-02-2011 08:23` to `31-10-2011 17:19`

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\prave\OneDrive\Desktop\ai-engineer-journey\csv_files\Online_Retail.csv",encoding='latin1')

# %% [markdown]
# #### Understaning Data

# %%
print(f"Total Rows {df.shape[0]}")
print(f"Total columns {df.shape[1]} ")
print(f"Total data points {df.shape[0] * df.shape[1]}")
# Out:
# Total Rows 541909
# Total columns 8
# Total data points 4335272

# %% [markdown]
# #### Understanding Columns

# %%
for i,column in enumerate(df.columns):
    print(f"{i+1}. {column}")
# Out:
# 1. InvoiceNo
# 2. StockCode
# 3. Description
# 4. Quantity
# 5. InvoiceDate
# 6. UnitPrice
# 7. CustomerID
# 8. Country

# %%
df.head()
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#         InvoiceDate  UnitPrice  CustomerID         Country
# 0  01-12-2010 08:26       2.55     17850.0  United Kingdom
# 1  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 2  01-12-2010 08:26       2.75     17850.0  United Kingdom
# 3  01-12-2010 08:26       3.39     17850.0  United Kingdom
# 4  01-12-2010 08:26       3.39     17850.0  United Kingdom

# %%
df.dtypes
# Out:
# InvoiceNo       object
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# UnitPrice      float64
# CustomerID     float64
# Country         object
# dtype: object

# %% [markdown]
# #### Busuiness Question

# %%
print(f"Total unique InvoiceNo - {df["InvoiceNo"].nunique()}")
print(f"Total unique StockID  - {df["StockCode"].nunique()}")
print(f"Total unique CustomerID - {df['CustomerID'].nunique()}")
# Out:
# Total unique InvoiceNo - 25900
# Total unique StockID  - 4070
# Total unique CustomerID - 4372

# %%
print(f"Top 10 most contires with transactions")
df['Country'].value_counts().head(10)
# Out:
# Top 10 most contires with transactions
# Country
# United Kingdom    495478
# Germany             9495
# France              8557
# EIRE                8196
# Spain               2533
# Netherlands         2371
# Belgium             2069
# Switzerland         2002
# Portugal            1519
# Australia           1259
# Name: count, dtype: int64

# %%
print("Top 10 Most sale Products")
df['Description'].value_counts().head(10)
# Out:
# Top 10 Most sale Products
# Description
# WHITE HANGING HEART T-LIGHT HOLDER    2369
# REGENCY CAKESTAND 3 TIER              2200
# JUMBO BAG RED RETROSPOT               2159
# PARTY BUNTING                         1727
# LUNCH BAG RED RETROSPOT               1638
# ASSORTED COLOUR BIRD ORNAMENT         1501
# SET OF 3 CAKE TINS PANTRY DESIGN      1473
# PACK OF 72 RETROSPOT CAKE CASES       1385
# LUNCH BAG  BLACK SKULL.               1350
# NATURAL SLATE HEART CHALKBOARD        1280
# Name: count, dtype: int64

# %%
print(f" Avg UnitPrice-{df['UnitPrice'].mean():.2f}")
# Out:
#  Avg Unit Price - 4.61

# %%
print(f"Data Range from {df['InvoiceDate'].min()} to {df['InvoiceDate'].max()}")
# Out:
# Data Range from 01-02-2011 08:23 to 31-10-2011 17:19

# %%
df['InvoiceNo'].count()
# Out:
# np.int64(541909)
